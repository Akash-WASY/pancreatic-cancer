# %%
# Import required libraries :
import pandas as pd
import numpy as np
mtdata = pd.read_excel("data/Mean Methylation Univariate freash.xlsx", sheet_name="U cox data 2")

# %%
ndf =mtdata.fillna(0).to_numpy()
dtd = ndf[:,3]
m = np.median(dtd[dtd > 0])
dtd[dtd==0]=m
np.savetxt('data/xvalue.dat', ndf[:,4:], fmt = "%f", delimiter = ',')
np.savetxt('data/yvalue.dat', list(zip(dtd , ndf[:,2])),  delimiter = ',', newline='\n' )

# %%
# %matplotlib inline

import sys
import scipy, importlib, pprint, matplotlib.pyplot as plt, warnings
from glmnet_py import glmnet; 
from glmnetPlot import glmnetPlot

# %%
x = scipy.loadtxt( 'data/xvalue.dat', dtype = scipy.float64, delimiter = ',')
y = scipy.loadtxt('data/yvalue.dat', dtype = scipy.float64, delimiter = ',')
# Out:
# /tmp/ipykernel_46568/2251109710.py:1: DeprecationWarning: scipy.loadtxt is deprecated and will be removed in SciPy 2.0.0, use numpy.loadtxt instead
#   x = scipy.loadtxt( 'data/xvalue.dat', dtype = scipy.float64, delimiter = ',')
# /tmp/ipykernel_46568/2251109710.py:2: DeprecationWarning: scipy.loadtxt is deprecated and will be removed in SciPy 2.0.0, use numpy.loadtxt instead
#   y = scipy.loadtxt('data/yvalue.dat', dtype = scipy.float64, delimiter = ',')

# %%
fit = glmnet(x = x.copy(), y = y.copy(), family = 'cox')
# Out:
# Warning: Cox model has no intercept!

# %%
glmnetPlot(fit);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 glmnetPlot(fit);
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/glmnet_py/glmnetPlot.py:84, in glmnetPlot(x, xvar, label, ptype, **options)
#      81 ptype = getFromList(ptype, ['coef', '2norm'], 'ptype should be one of ''coef'', ''2norm'' ')
#      83 if x['class'] in ['elnet', 'lognet', 'coxnet', 'fishnet']:
# ---> 84     handle = plotCoef(x['beta'], [], x['lambdau'], x['df'], x['dev'],
#      85     label, xvar, '', 'Coefficients', **options)
#      87 elif x['class'] in ['multnet', 'mrelnet']:
#      88     beta = x['beta']
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/glmnet_py/glmnetPlot.py:208, in plotCoef(beta, norm, lambdau, df, dev, label, xvar, xlab, ylab, **options)
#     205 prettydf = df[indat]
#     206 prettydf[-1] = df[-1]
# --> 208 ax2.set(XLim=[min(index), max(index)], XTicks = atdf, XTickLabels = prettydf)
#     209 ax2.grid()
#     210 ax1.yaxis.grid()
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File /media/technophilix/New Volume/research-work-2023/pancreatic_cancer/venv/lib/python3.10/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'XLim'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

sns.boxplot(x = fit['lambdau'], y = fit['beta'][0], ax = ax)
sns.stripplot(x = fit['lambdau'], y = fit['beta'][0], jitter = 0.2, color = 'red', ax = ax)
plt.xscale('log')
plt.xlabel('log(λ)')
plt.ylabel('C-Index')
plt.title('Coefficient Paths')
plt.show()

# Plot heatmap of coefficients
sns.heatmap(fit['beta'], cmap='coolwarm', xticklabels=False, yticklabels=False)
plt.xlabel('Features')
plt.ylabel('Lambdas')
plt.title('Coefficient Heatmap')
plt.show()

# %%
fit
# Out:
# {'beta': array([[ 0.00000000e+00, -1.23145502e-04, -2.50352877e-04, ...,
#          -2.11990704e-02, -2.15534724e-02, -2.19002499e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           1.03996758e+01,  1.04398627e+01,  1.04765190e+01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -6.54507308e+00, -6.58403523e+00, -6.61959724e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -5.53174722e+00, -5.55257858e+00, -5.57135736e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -7.60451702e+00, -7.61948808e+00, -7.63294723e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           2.70703071e+00,  2.71010266e+00,  2.71291347e+00]]),
#  'dev': array([0.        , 0.00554548, 0.01076543, 0.01568236, 0.02046805,
#         0.0258712 , 0.03093783, 0.03570796, 0.04011979, 0.04418047,
#         0.04790138, 0.05134808, 0.0562642 , 0.06097356, 0.06551779,
#         0.06979479, 0.07416621, 0.07827017, 0.08301929, 0.08790225,
#         0.09331195, 0.09886506, 0.10362926, 0.10772159, 0.11167555,
#         0.11564492, 0.11979498, 0.12356156, 0.12677021, 0.13009698,
#         0.13291502, 0.13564623, 0.1381666 , 0.14105869, 0.1437823 ,
#         0.14631405, 0.14855217, 0.15063725, 0.15252696, 0.15431341,
#         0.1560467 , 0.15753824, 0.1593454 , 0.1612971 , 0.16327603,
#         0.16514539, 0.16673347, 0.1681456 , 0.16950452, 0.17066883,
#         0.1716585 , 0.17251247, 0.17325346, 0.17388301, 0.17442325,
#         0.17488664, 0.17528606, 0.17563033, 0.17592759, 0.17618546,
#         0.17641089, 0.17660813, 0.17679205, 0.17695921, 0.17710665,
#         0.17723507, 0.17734878, 0.17744987, 0.17753959, 0.17761982,
#         0.17769171, 0.1777562 , 0.17781453, 0.17786784, 0.17791724,
#         0.17796229, 0.17800335, 0.17804093]),
#  'nulldev': 783.4942219511505,
#  'df': array([ 0,  1,  1,  1,  2,  2,  3,  3,  3,  3,  3,  3,  5,  8,  8,  9, 10,
#         10, 12, 13, 14, 14, 14, 14, 16, 18, 21, 20, 22, 22, 22, 25, 26, 29,
#         30, 30, 31, 32, 33, 36, 37, 37, 39, 40, 43, 43, 43, 45, 46, 46, 45,
#         46, 45, 45, 45, 45, 45, 44, 44, 44, 45, 45, 47, 47, 46, 46, 46, 46,
#         46, 45, 45, 45, 45, 47, 47, 47, 47, 46]),
#  'lambdau': array([1.98826833e-01, 1.81163605e-01, 1.65069530e-01, 1.50405208e-01,
#         1.37043624e-01, 1.24869046e-01, 1.13776024e-01, 1.03668476e-01,
#         9.44588539e-02, 8.60673897e-02, 7.84214000e-02, 7.14546590e-02,
#         6.51068240e-02, 5.93229132e-02, 5.40528291e-02, 4.92509247e-02,
#         4.48756083e-02, 4.08889830e-02, 3.72565184e-02, 3.39467520e-02,
#         3.09310161e-02, 2.81831899e-02, 2.56794730e-02, 2.33981794e-02,
#         2.13195496e-02, 1.94255796e-02, 1.76998646e-02, 1.61274574e-02,
#         1.46947386e-02, 1.33892985e-02, 1.21998301e-02, 1.11160308e-02,
#         1.01285133e-02, 9.22872408e-03, 8.40886967e-03, 7.66184887e-03,
#         6.98119133e-03, 6.36100153e-03, 5.79590769e-03, 5.28101522e-03,
#         4.81186439e-03, 4.38439162e-03, 3.99489435e-03, 3.63999895e-03,
#         3.31663147e-03, 3.02199107e-03, 2.75352571e-03, 2.50891008e-03,
#         2.28602542e-03, 2.08294122e-03, 1.89789847e-03, 1.72929440e-03,
#         1.57566865e-03, 1.43569059e-03, 1.30814779e-03, 1.19193555e-03,
#         1.08604728e-03, 9.89565834e-04, 9.01655532e-04, 8.21554940e-04,
#         7.48570263e-04, 6.82069344e-04, 6.21476184e-04, 5.66265952e-04,
#         5.15960446e-04, 4.70123942e-04, 4.28359427e-04, 3.90305156e-04,
#         3.55631521e-04, 3.24038197e-04, 2.95251537e-04, 2.69022204e-04,
#         2.45123013e-04, 2.23346960e-04, 2.03505432e-04, 1.85426570e-04,
#         1.68953785e-04, 1.53944396e-04]),
#  'npasses': 20738,
#  'jerr': 0,
#  'dim': array([48, 78]),
#  'offset': False,
#  'class': 'coxnet'}

# %%
np.log(fit['lambdau'])
# Out:
# array([-1.61532102, -1.70835476, -1.8013885 , -1.89442224, -1.98745598,
#        -2.08048972, -2.17352347, -2.26655721, -2.35959095, -2.45262469,
#        -2.54565843, -2.63869217, -2.73172591, -2.82475965, -2.91779339,
#        -3.01082714, -3.10386088, -3.19689462, -3.28992836, -3.3829621 ,
#        -3.47599584, -3.56902958, -3.66206332, -3.75509706, -3.84813081,
#        -3.94116455, -4.03419829, -4.12723203, -4.22026577, -4.31329951,
#        -4.40633325, -4.49936699, -4.59240073, -4.68543448, -4.77846822,
#        -4.87150196, -4.9645357 , -5.05756944, -5.15060318, -5.24363692,
#        -5.33667066, -5.4297044 , -5.52273815, -5.61577189, -5.70880563,
#        -5.80183937, -5.89487311, -5.98790685, -6.08094059, -6.17397433,
#        -6.26700808, -6.36004182, -6.45307556, -6.5461093 , -6.63914304,
#        -6.73217678, -6.82521052, -6.91824426, -7.011278  , -7.10431175,
#        -7.19734549, -7.29037923, -7.38341297, -7.47644671, -7.56948045,
#        -7.66251419, -7.75554793, -7.84858167, -7.94161542, -8.03464916,
#        -8.1276829 , -8.22071664, -8.31375038, -8.40678412, -8.49981786,
#        -8.5928516 , -8.68588534, -8.77891909])

# %%
# Plot pairplot of coefficients
sns.pairplot(pd.DataFrame(fit['beta']), diag_kind='hist', corner=True)
plt.suptitle('Coefficient Pairplot', y=1.05)
plt.show()

# %%
sns.heatmap(fit['beta']*(0.5), cmap='crest', xticklabels=False, yticklabels=False)
plt.xlabel('Features')
plt.ylabel('Lambdas')
plt.title('Coefficient Heatmap')
plt.show()
