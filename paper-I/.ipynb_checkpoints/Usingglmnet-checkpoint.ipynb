# %%
# Import required libraries :
import pandas as pd
import numpy as np
import glmnet_python
from glmnet import glmnet
import matplotlib.pyplot as plt
import scipy, importlib, pprint, matplotlib.pyplot as plt, warnings
from glmnet import glmnet; from glmnetPlot import glmnetPlot
from glmnetPrint import glmnetPrint; from glmnetCoef import glmnetCoef; from glmnetPredict import glmnetPredict
from cvglmnet import cvglmnet; from cvglmnetCoef import cvglmnetCoef
from cvglmnetPlot import cvglmnetPlot; from cvglmnetPredict import cvglmnetPredict
mtdata = pd.read_excel("Mean Methylation Univariate.xlsx", sheet_name="U cox data 2")
# Out:
# /usr/lib/python3/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
ndf =mtdata.fillna(0).to_numpy()
dtd = ndf[:,3]
m = np.median(dtd[dtd > 0])
dtd[dtd==0]=m
np.savetxt('xvalue.dat', ndf[:,4:], fmt = "%f", delimiter = ',')
np.savetxt('yvalue.dat', list(zip(dtd , ndf[:,2])),  delimiter = ',', newline='\n' )

# %%
# %matplotlib inline

import sys
import scipy, importlib, pprint, matplotlib.pyplot as plt, warnings
from glmnet_py import glmnet; 
from glmnetPlot import glmnetPlot 
from glmnetPrint import glmnetPrint; from glmnetCoef import glmnetCoef; from glmnetPredict import glmnetPredict
from cvglmnet import cvglmnet; from cvglmnetCoef import cvglmnetCoef
from cvglmnetPlot import cvglmnetPlot; from cvglmnetPredict import cvglmnetPredict

# %%
x = scipy.loadtxt( 'xvalue.dat', dtype = scipy.float64, delimiter = ',')
y = scipy.loadtxt('yvalue.dat', dtype = scipy.float64, delimiter = ',')
# Out:
# /tmp/ipykernel_3542/1356569892.py:1: DeprecationWarning: scipy.loadtxt is deprecated and will be removed in SciPy 2.0.0, use numpy.loadtxt instead
#   x = scipy.loadtxt( 'xvalue.dat', dtype = scipy.float64, delimiter = ',')
# /tmp/ipykernel_3542/1356569892.py:2: DeprecationWarning: scipy.loadtxt is deprecated and will be removed in SciPy 2.0.0, use numpy.loadtxt instead
#   y = scipy.loadtxt('yvalue.dat', dtype = scipy.float64, delimiter = ',')

# %%
 fit = glmnet(x = x.copy(), y = y.copy(), family = 'cox')
# Out:
# Warning: Cox model has no intercept!

# %%
glmnetPlot(fit);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 glmnetPlot(fit);
#
# File ~/.local/lib/python3.10/site-packages/glmnet_python/glmnetPlot.py:84, in glmnetPlot(x, xvar, label, ptype, **options)
#      81 ptype = getFromList(ptype, ['coef', '2norm'], 'ptype should be one of ''coef'', ''2norm'' ')
#      83 if x['class'] in ['elnet', 'lognet', 'coxnet', 'fishnet']:
# ---> 84     handle = plotCoef(x['beta'], [], x['lambdau'], x['df'], x['dev'],
#      85     label, xvar, '', 'Coefficients', **options)
#      87 elif x['class'] in ['multnet', 'mrelnet']:
#      88     beta = x['beta']
#
# File ~/.local/lib/python3.10/site-packages/glmnet_python/glmnetPlot.py:208, in plotCoef(beta, norm, lambdau, df, dev, label, xvar, xlab, ylab, **options)
#     205 prettydf = df[indat]
#     206 prettydf[-1] = df[-1]
# --> 208 ax2.set(XLim=[min(index), max(index)], XTicks = atdf, XTickLabels = prettydf)
#     209 ax2.grid()
#     210 ax1.yaxis.grid()
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:116, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     108 if not hasattr(cls.set, '_autogenerated_signature'):
#     109     # Don't overwrite cls.set if the subclass or one of its parents
#     110     # has defined a set method set itself.
#     111     # If there was no explicit definition, cls.set is inherited from
#     112     # the hierarchy of auto-generated set methods, which hold the
#     113     # flag _autogenerated_signature.
#     114     return
# --> 116 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:1164, in Artist.set(self, **kwargs)
#    1159 def set(self, **kwargs):
#    1160     # docstring and signature are auto-generated via
#    1161     # Artist._update_set_signature_and_docstring() at the end of the
#    1162     # module.
#    1163     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164     return self.update(kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'AxesSubplot' object has no property 'XLim'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

sns.boxplot(x = fit['lambdau'], y = fit['beta'][0], ax = ax)
sns.stripplot(x = fit['lambdau'], y = fit['beta'][0], jitter = 0.2, color = 'red', ax = ax)
plt.xscale('log')
plt.xlabel('log(λ)')
plt.ylabel('C-Index')
plt.title('Coefficient Paths')
plt.show()

# Plot heatmap of coefficients
sns.heatmap(fit['beta'], cmap='coolwarm', xticklabels=False, yticklabels=False)
plt.xlabel('Features')
plt.ylabel('Lambdas')
plt.title('Coefficient Heatmap')
plt.show()

# %%
fit

# %%
np.log(fit['lambdau'])

# %%
# Plot pairplot of coefficients
sns.pairplot(pd.DataFrame(fit['beta']), diag_kind='hist', corner=True)
plt.suptitle('Coefficient Pairplot', y=1.05)
plt.show()
