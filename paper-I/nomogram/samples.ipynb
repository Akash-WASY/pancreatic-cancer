# %%
import simpleNomo
import pandas as pd

# %%
path = "template.xlsx"

### check the excel template
pd.read_excel(path)
# Out:
#         feature    coef  min   max        type  position
# 0     intercept -1.2926  NaN   NaN         NaN       NaN
# 1     threshold  0.5243  NaN   NaN         NaN       NaN
# 2        Gender  0.0322  0.0   1.0     nominal       NaN
# 3        Tstage -0.0696  0.0   2.0     nominal       NaN
# 4  Years smoked -0.5492  0.0  75.0  continuous       NaN
# 5          Race  0.0963  0.0   1.0     nominal       NaN
# 6   Lymph nodes -0.0771  0.0  16.0  continuous       NaN

# %%
### construct nomograms
cmv_nomo = simpleNomo.nomogram(path)
# Out:
# C:\Users\PRANTIK\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpleNomo\__init__.py:281: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   maxi = float(d["max"])
# C:\Users\PRANTIK\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpleNomo\__init__.py:282: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mini = float(d["min"])
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# ...

# %%
### personalize the nomogram
cmv_nomo_personalize = simpleNomo.nomogram(path, 
                                           result_title="Risk for CMV", # change the title for the mapping graph
                                           fig_width=8, # change the width of the figure
                                           single_height=0.6, # change the height of each axis
                                           total_point=20,  # chage the maximum point of each variable
                                           dpi=80,  ### change the resolution
                                           ax_para = {"c":"green", "linewidth":1.3, "linestyle": "-"}, # chagne the paramters for each axis, for example here green
                                           xtick_para = {"fontsize": 10, "fontfamily": "times new roman"}, # change the parameters for the ticks of each axis, 
                                           ylabel_para = {"fontsize": 18, "fontname": "Songti Sc", "labelpad":150, 
                                                          "loc": "center", "color": "black", "rotation":"horizontal"},) # change the parameters for the variable name
# Out:
# C:\Users\PRANTIK\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpleNomo\__init__.py:281: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   maxi = float(d["max"])
# C:\Users\PRANTIK\AppData\Local\Programs\Python\Python311\Lib\site-packages\simpleNomo\__init__.py:282: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mini = float(d["min"])
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# findfont: Font family 'Songti Sc' not found.
# ...
